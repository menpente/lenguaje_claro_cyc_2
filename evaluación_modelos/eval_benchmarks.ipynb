# %% [markdown]
# <a href="https://colab.research.google.com/github/menpente/lenguaje_claro_cyc_2/blob/main/evaluaci%C3%B3n_modelos/eval_benchmarks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install litgpt
# !pip install git+https://github.com/EleutherAI/lm-evaluation-harness.git
# Out:
# Requirement already satisfied: litgpt in /usr/local/lib/python3.10/dist-packages (0.4.12)
# Requirement already satisfied: torch>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from litgpt) (2.4.0+cu121)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from litgpt) (1.26.4)
# Requirement already satisfied: lightning==2.4.0.dev20240728 in /usr/local/lib/python3.10/dist-packages (from litgpt) (2.4.0.dev20240728)
# Requirement already satisfied: jsonargparse>=4.27.6 in /usr/local/lib/python3.10/dist-packages (from jsonargparse[signatures]>=4.27.6->litgpt) (4.32.1)
# Requirement already satisfied: huggingface-hub>=0.23.5 in /usr/local/lib/python3.10/dist-packages (from litgpt) (0.24.6)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from litgpt) (0.4.5)
# Requirement already satisfied: tokenizers>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from litgpt) (0.19.1)
# Requirement already satisfied: tqdm>=4.66.0 in /usr/local/lib/python3.10/dist-packages (from litgpt) (4.66.5)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.10/dist-packages (from lightning==2.4.0.dev20240728->litgpt) (6.0.2)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning==2.4.0.dev20240728->litgpt) (2024.6.1)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from lightning==2.4.0.dev20240728->litgpt) (0.11.7)
# Requirement already satisfied: packaging<25.0,>=20.0 in /usr/local/lib/python3.10/dist-packages (from lightning==2.4.0.dev20240728->litgpt) (24.1)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from lightning==2.4.0.dev20240728->litgpt) (1.4.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from lightning==2.4.0.dev20240728->litgpt) (4.12.2)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.10/dist-packages (from lightning==2.4.0.dev20240728->litgpt) (2.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.5->litgpt) (3.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.5->litgpt) (2.32.3)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.10/dist-packages (from jsonargparse[signatures]>=4.27.6->litgpt) (0.16)
# Requirement already satisfied: typeshed-client>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from jsonargparse[signatures]>=4.27.6->litgpt) (2.7.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->litgpt) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->litgpt) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.2.0->litgpt) (3.1.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning==2.4.0.dev20240728->litgpt) (3.10.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities<2.0,>=0.10.0->lightning==2.4.0.dev20240728->litgpt) (71.0.4)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from typeshed-client>=2.1.0->jsonargparse[signatures]>=4.27.6->litgpt) (6.4.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.2.0->litgpt) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.23.5->litgpt) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.23.5->litgpt) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.23.5->litgpt) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.23.5->litgpt) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.2.0->litgpt) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.4.0.dev20240728->litgpt) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.4.0.dev20240728->litgpt) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.4.0.dev20240728->litgpt) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.4.0.dev20240728->litgpt) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.4.0.dev20240728->litgpt) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.4.0.dev20240728->litgpt) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.4.0.dev20240728->litgpt) (4.0.3)
# Collecting git+https://github.com/EleutherAI/lm-evaluation-harness.git
#   Cloning https://github.com/EleutherAI/lm-evaluation-harness.git to /tmp/pip-req-build-t5wa_ytg
#   Running command git clone --filter=blob:none --quiet https://github.com/EleutherAI/lm-evaluation-harness.git /tmp/pip-req-build-t5wa_ytg
#   Resolved https://github.com/EleutherAI/lm-evaluation-harness.git to commit fb963f0f0a5b28b69763590bb59676072cf43a01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.4) (0.34.2)
# Collecting evaluate (from lm_eval==0.4.4)
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: datasets>=2.16.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.4) (3.0.0)
# Requirement already satisfied: jsonlines in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.4) (4.0.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.4) (2.10.1)
# Collecting peft>=0.2.0 (from lm_eval==0.4.4)
#   Downloading peft-0.12.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pybind11>=2.6.2 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.4) (2.13.5)
# Requirement already satisfied: pytablewriter in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.4) (1.2.0)
# Requirement already satisfied: rouge-score>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.4) (0.1.2)
# Requirement already satisfied: sacrebleu>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.4) (1.5.0)
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.4) (1.3.2)
# Requirement already satisfied: sqlitedict in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.4) (2.1.0)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.4) (2.4.0+cu121)
# Requirement already satisfied: tqdm-multiprocess in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.4) (0.0.11)
# Requirement already satisfied: transformers>=4.1 in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.4) (4.44.2)
# Requirement already satisfied: zstandard in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.4) (0.23.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.4) (0.3.8)
# Collecting word2number (from lm_eval==0.4.4)
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from lm_eval==0.4.4) (10.3.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.4) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.4) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.4) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.4) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.4) (0.24.6)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.26.0->lm_eval==0.4.4) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.4) (3.16.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.4) (17.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.4) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.4) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.4) (4.66.5)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.4) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.4) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets>=2.16.0->lm_eval==0.4.4) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->lm_eval==0.4.4) (3.10.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.4) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.4) (3.8.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score>=0.0.4->lm_eval==0.4.4) (1.16.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.5.0->lm_eval==0.4.4) (2.10.1)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.4) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.4) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.1->lm_eval==0.4.4) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.4) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.4) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.4) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->lm_eval==0.4.4) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.1->lm_eval==0.4.4) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.1->lm_eval==0.4.4) (0.19.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines->lm_eval==0.4.4) (24.2.0)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.4) (71.0.4)
# Requirement already satisfied: DataProperty<2,>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.4) (1.0.1)
# Requirement already satisfied: mbstrdecoder<2,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.4) (1.1.3)
# Requirement already satisfied: pathvalidate<4,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.4) (3.2.1)
# Requirement already satisfied: tabledata<2,>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.4) (1.3.3)
# Requirement already satisfied: tcolorpy<1,>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from pytablewriter->lm_eval==0.4.4) (0.1.6)
# Requirement already satisfied: typepy<2,>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.4) (1.3.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from tqdm-multiprocess->lm_eval==0.4.4) (0.4.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.4) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.4) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.4) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.4) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.4) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->lm_eval==0.4.4) (4.0.3)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter->lm_eval==0.4.4) (5.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.4) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.4) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.4) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->lm_eval==0.4.4) (2024.8.30)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.4) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm_eval==0.4.4) (2024.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8->lm_eval==0.4.4) (2.1.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score>=0.0.4->lm_eval==0.4.4) (8.1.7)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->lm_eval==0.4.4) (2024.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8->lm_eval==0.4.4) (1.3.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 1.7 MB/s eta 0:00:00
# Downloading peft-0.12.0-py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 9.8 MB/s eta 0:00:00
# Building wheels for collected packages: lm_eval, word2number
#   Building wheel for lm_eval (pyproject.toml) ... done
#   Created wheel for lm_eval: filename=lm_eval-0.4.4-py3-none-any.whl size=2256864 sha256=f218d1d29393c03937bbbedc28ad8c1baeb6efaf1d9dbd79fd631286276b9c84
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wrlynae4/wheels/ff/d5/f4/949f2b285369fc332f8dbba43f220ebd88387ee2f2c0c1174f
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5570 sha256=7e2588949207f9bc4d35b19bc7f95d9463ce236b7695ba454fc74796a092ad1b
#   Stored in directory: /root/.cache/pip/wheels/84/ff/26/d3cfbd971e96c5aa3737ecfced81628830d7359b55fbb8ca3b
# Successfully built lm_eval word2number
# Installing collected packages: word2number, peft, evaluate, lm_eval
# Successfully installed evaluate-0.4.3 lm_eval-0.4.4 peft-0.12.0 word2number-1.1

# %%
# !litgpt evaluate microsoft/phi-2 --tasks 'truthfulqa_mc2,mmlu'
# Out:
# {'access_token': None,
#  'batch_size': 1,
#  'checkpoint_dir': PosixPath('checkpoints/microsoft/phi-2'),
#  'device': None,
#  'dtype': None,
#  'force_conversion': False,
#  'limit': None,
#  'num_fewshot': None,
#  'out_dir': None,
#  'save_filepath': None,
#  'seed': 1234,
#  'tasks': 'truthfulqa_mc2,mmlu'}
# 2024-09-13 19:03:14.428817: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-13 19:03:14.460956: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-13 19:03:14.470597: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-13 19:03:14.493879: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-13 19:03:16.371728: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-09-13:19:03:18,700 INFO     [huggingface.py:130] Using device 'cpu'
# 2024-09-13:19:03:18,862 INFO     [huggingface.py:366] Model parallel was set to False, max memory was not set, and device map was set to {'': 'cpu'}
# 2024-09-13:19:03:56,877 INFO     [evaluator.py:161] Setting random seed to 1234 | Setting numpy seed to 1234 | Setting torch manual seed to 1234
# 2024-09-13:19:03:56,878 INFO     [evaluator.py:214] Using pre-initialized model
# 2024-09-13:19:03:57,334 INFO     [__init__.py:491] `group` and `group_alias` keys in TaskConfigs are deprecated and will be removed in v0.4.5 of lm_eval. The new `tag` field will be used to allow for a shortcut to a group of tasks one does not wish to aggregate metrics across. `group`s which aggregate across subtasks must be only defined in a separate group config file, which will be the official way to create groups that support cross-task aggregation as in `mmlu`. Please see the v0.4.4 patch notes and our documentation: https://github.com/EleutherAI/lm-evaluation-harness/blob/main/docs/new_task_guide.md#advanced-group-configs for more information.
# README.md: 100% 9.59k/9.59k [00:00<00:00, 26.5MB/s]
# validation-00000-of-00001.parquet: 100% 271k/271k [00:00<00:00, 6.49MB/s]
# Generating validation split: 100% 817/817 [00:00<00:00, 3846.69 examples/s]
# mmlu_no_train.py: 100% 5.86k/5.86k [00:00<00:00, 21.4MB/s]
# README.md: 100% 1.11k/1.11k [00:00<00:00, 5.06MB/s]
# data.tar: 100% 166M/166M [00:03<00:00, 52.1MB/s]
# Generating test split: 108 examples [00:00, 164.68 examples/s]
# Generating validation split: 11 examples [00:00, 1096.37 examples/s]
# Generating dev split: 5 examples [00:00,  8.07 examples/s]
# Generating test split: 895 examples [00:00, 1437.03 examples/s]
# Generating validation split: 100 examples [00:00, 8877.21 examples/s]
# Generating dev split: 5 examples [00:00,  9.46 examples/s]
# Generating test split: 346 examples [00:00, 617.23 examples/s]
# Generating validation split: 38 examples [00:00, 2186.33 examples/s]
# Generating dev split: 5 examples [00:00,  9.06 examples/s]
# Generating test split: 163 examples [00:00, 294.94 examples/s]
# Generating validation split: 18 examples [00:00, 1882.82 examples/s]
# Generating dev split: 5 examples [00:00,  8.51 examples/s]
# Generating test split: 324 examples [00:00, 575.29 examples/s]
# Generating validation split: 35 examples [00:00, 2667.70 examples/s]
# Generating dev split: 5 examples [00:00, 10.91 examples/s]
# Generating test split: 126 examples [00:00, 278.96 examples/s]
# Generating validation split: 14 examples [00:00, 2717.65 examples/s]
# Generating dev split: 5 examples [00:00, 10.20 examples/s]
# Generating test split: 121 examples [00:00, 266.59 examples/s]
# Generating validation split: 13 examples [00:00, 1896.95 examples/s]
# Generating dev split: 5 examples [00:00, 10.72 examples/s]
# Generating test split: 171 examples [00:00, 591.92 examples/s]
# Generating validation split: 19 examples [00:00, 3753.38 examples/s]
# Generating dev split: 5 examples [00:00, 13.89 examples/s]
# Generating test split: 311 examples [00:00, 501.44 examples/s]
# Generating validation split: 34 examples [00:00, 4520.58 examples/s]
# Generating dev split: 5 examples [00:00,  7.82 examples/s]
# Generating test split: 165 examples [00:00, 361.20 examples/s]
# Generating validation split: 18 examples [00:00, 1728.58 examples/s]
# Generating dev split: 5 examples [00:00, 12.15 examples/s]
# Generating test split: 1534 examples [00:00, 2406.00 examples/s]
# Generating validation split: 170 examples [00:00, 5249.13 examples/s]
# Generating dev split: 5 examples [00:00, 10.34 examples/s]
# Generating test split: 237 examples [00:00, 464.64 examples/s]
# Generating validation split: 26 examples [00:00, 1574.17 examples/s]
# Generating dev split: 5 examples [00:00, 11.93 examples/s]
# Generating test split: 204 examples [00:00, 440.53 examples/s]
# Generating validation split: 22 examples [00:00, 1131.39 examples/s]
# Generating dev split: 5 examples [00:00, 11.99 examples/s]
# Generating test split: 612 examples [00:00, 1466.38 examples/s]
# Generating validation split: 69 examples [00:00, 3698.40 examples/s]
# Generating dev split: 5 examples [00:00, 14.60 examples/s]
# Generating test split: 245 examples [00:00, 937.27 examples/s]
# Generating validation split: 27 examples [00:00, 1110.61 examples/s]
# Generating dev split: 5 examples [00:00, 30.22 examples/s]
# Generating test split: 390 examples [00:00, 1805.56 examples/s]
# Generating validation split: 43 examples [00:00, 3414.72 examples/s]
# Generating dev split: 5 examples [00:00, 29.32 examples/s]
# Generating test split: 238 examples [00:00, 1193.59 examples/s]
# Generating validation split: 26 examples [00:00, 1894.74 examples/s]
# Generating dev split: 5 examples [00:00, 38.29 examples/s]
# Generating test split: 193 examples [00:00, 1612.06 examples/s]
# Generating validation split: 21 examples [00:00, 4173.24 examples/s]
# Generating dev split: 5 examples [00:00, 43.58 examples/s]
# Generating test split: 131 examples [00:00, 1163.12 examples/s]
# Generating validation split: 12 examples [00:00, 2198.85 examples/s]
# Generating dev split: 5 examples [00:00, 47.03 examples/s]
# Generating test split: 198 examples [00:00, 1584.17 examples/s]
# Generating validation split: 22 examples [00:00, 4587.36 examples/s]
# Generating dev split: 5 examples [00:00, 44.94 examples/s]
# Generating test split: 545 examples [00:00, 3976.38 examples/s]
# Generating validation split: 60 examples [00:00, 6126.20 examples/s]
# Generating dev split: 5 examples [00:00, 45.61 examples/s]
# Generating test split: 100 examples [00:00, 779.92 examples/s]
# Generating validation split: 11 examples [00:00, 2325.59 examples/s]
# Generating dev split: 5 examples [00:00, 47.32 examples/s]
# Generating test split: 114 examples [00:00, 1026.31 examples/s]
# Generating validation split: 12 examples [00:00, 2557.63 examples/s]
# Generating dev split: 5 examples [00:00, 42.97 examples/s]
# Generating test split: 201 examples [00:00, 1819.81 examples/s]
# Generating validation split: 22 examples [00:00, 3087.25 examples/s]
# Generating dev split: 5 examples [00:00, 46.73 examples/s]
# Generating test split: 110 examples [00:00, 999.89 examples/s]
# Generating validation split: 12 examples [00:00, 2174.72 examples/s]
# Generating dev split: 5 examples [00:00, 47.74 examples/s]
# Generating test split: 100 examples [00:00, 933.17 examples/s]
# Generating validation split: 11 examples [00:00, 2030.60 examples/s]
# Generating dev split: 5 examples [00:00, 45.95 examples/s]
# Generating test split: 282 examples [00:00, 2219.99 examples/s]
# Generating validation split: 31 examples [00:00, 2090.95 examples/s]
# Generating dev split: 5 examples [00:00, 47.33 examples/s]
# Generating test split: 234 examples [00:00, 1993.92 examples/s]
# Generating validation split: 25 examples [00:00, 3789.30 examples/s]
# Generating dev split: 5 examples [00:00, 48.31 examples/s]
# Generating test split: 100 examples [00:00, 973.76 examples/s]
# Generating validation split: 10 examples [00:00, 2451.52 examples/s]
# Generating dev split: 5 examples [00:00, 46.84 examples/s]
# Generating test split: 306 examples [00:00, 2481.93 examples/s]
# Generating validation split: 33 examples [00:00, 5142.94 examples/s]
# Generating dev split: 5 examples [00:00, 33.24 examples/s]
# Generating test split: 783 examples [00:00, 2985.41 examples/s]
# Generating validation split: 86 examples [00:00, 5650.49 examples/s]
# Generating dev split: 5 examples [00:00, 33.15 examples/s]
# Generating test split: 272 examples [00:00, 1425.05 examples/s]
# Generating validation split: 31 examples [00:00, 2632.21 examples/s]
# Generating dev split: 5 examples [00:00, 28.26 examples/s]
# Generating test split: 166 examples [00:00, 896.74 examples/s]
# Generating validation split: 18 examples [00:00, 1791.54 examples/s]
# Generating dev split: 5 examples [00:00, 27.27 examples/s]
# Generating test split: 265 examples [00:00, 1261.16 examples/s]
# Generating validation split: 29 examples [00:00, 1470.85 examples/s]
# Generating dev split: 5 examples [00:00, 25.72 examples/s]
# Generating test split: 173 examples [00:00, 1550.73 examples/s]
# Generating validation split: 22 examples [00:00, 4102.37 examples/s]
# Generating dev split: 5 examples [00:00, 46.94 examples/s]
# Generating test split: 103 examples [00:00, 975.86 examples/s]
# Generating validation split: 11 examples [00:00, 2100.30 examples/s]
# Generating dev split: 5 examples [00:00, 47.52 examples/s]
# Generating test split: 100 examples [00:00, 905.88 examples/s]
# Generating validation split: 11 examples [00:00, 2908.67 examples/s]
# Generating dev split: 5 examples [00:00, 48.38 examples/s]
# Generating test split: 223 examples [00:00, 1960.49 examples/s]
# Generating validation split: 23 examples [00:00, 3409.52 examples/s]
# Generating dev split: 5 examples [00:00, 43.47 examples/s]
# Generating test split: 235 examples [00:00, 2053.16 examples/s]
# Generating validation split: 26 examples [00:00, 5638.96 examples/s]
# Generating dev split: 5 examples [00:00, 47.68 examples/s]
# Generating test split: 112 examples [00:00, 1075.09 examples/s]
# Generating validation split: 11 examples [00:00, 2589.51 examples/s]
# Generating dev split: 5 examples [00:00, 47.53 examples/s]
# Generating test split: 135 examples [00:00, 1196.07 examples/s]
# Generating validation split: 14 examples [00:00, 3622.25 examples/s]
# Generating dev split: 5 examples [00:00, 49.16 examples/s]
# Generating test split: 102 examples [00:00, 933.48 examples/s]
# Generating validation split: 11 examples [00:00, 2720.04 examples/s]
# Generating dev split: 5 examples [00:00, 46.92 examples/s]
# Generating test split: 144 examples [00:00, 1361.26 examples/s]
# Generating validation split: 16 examples [00:00, 2599.91 examples/s]
# Generating dev split: 5 examples [00:00, 47.03 examples/s]
# Generating test split: 145 examples [00:00, 1382.41 examples/s]
# Generating validation split: 16 examples [00:00, 2836.98 examples/s]
# Generating dev split: 5 examples [00:00, 46.82 examples/s]
# Generating test split: 100 examples [00:00, 881.97 examples/s]
# Generating validation split: 11 examples [00:00, 2108.65 examples/s]
# Generating dev split: 5 examples [00:00, 41.88 examples/s]
# Generating test split: 100 examples [00:00, 881.61 examples/s]
# Generating validation split: 11 examples [00:00, 1900.77 examples/s]
# Generating dev split: 5 examples [00:00, 44.90 examples/s]
# Generating test split: 310 examples [00:00, 2569.48 examples/s]
# Generating validation split: 32 examples [00:00, 5866.16 examples/s]
# Generating dev split: 5 examples [00:00, 47.43 examples/s]
# Generating test split: 203 examples [00:00, 1219.11 examples/s]
# Generating validation split: 22 examples [00:00, 2267.75 examples/s]
# Generating dev split: 5 examples [00:00, 31.37 examples/s]
# Generating test split: 100 examples [00:00, 614.13 examples/s]
# Generating validation split: 8 examples [00:00, 790.52 examples/s]
# Generating dev split: 5 examples [00:00, 30.37 examples/s]
# Generating test split: 100 examples [00:00, 549.64 examples/s]
# Generating validation split: 11 examples [00:00, 1464.63 examples/s]
# Generating dev split: 5 examples [00:00, 28.45 examples/s]
# Generating test split: 270 examples [00:00, 1349.70 examples/s]
# Generating validation split: 29 examples [00:00, 2792.86 examples/s]
# Generating dev split: 5 examples [00:00, 28.76 examples/s]
# Generating test split: 100 examples [00:00, 869.97 examples/s]
# Generating validation split: 9 examples [00:00, 2518.60 examples/s]
# Generating dev split: 5 examples [00:00, 47.88 examples/s]
# Generating test split: 100 examples [00:00, 940.01 examples/s]
# Generating validation split: 11 examples [00:00, 2675.71 examples/s]
# Generating dev split: 5 examples [00:00, 46.60 examples/s]
# Generating test split: 216 examples [00:00, 1796.89 examples/s]
# Generating validation split: 23 examples [00:00, 4251.05 examples/s]
# Generating dev split: 5 examples [00:00, 47.52 examples/s]
# Generating test split: 152 examples [00:00, 1438.08 examples/s]
# Generating validation split: 16 examples [00:00, 4175.77 examples/s]
# Generating dev split: 5 examples [00:00, 47.46 examples/s]
# Generating test split: 151 examples [00:00, 1222.11 examples/s]
# Generating validation split: 17 examples [00:00, 3258.98 examples/s]
# Generating dev split: 5 examples [00:00, 42.54 examples/s]
# Generating test split: 378 examples [00:00, 3014.23 examples/s]
# Generating validation split: 41 examples [00:00, 5206.84 examples/s]
# Generating dev split: 5 examples [00:00, 47.46 examples/s]
# 2024-09-13:19:05:16,247 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,248 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,248 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,248 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,248 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,248 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,248 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,248 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,248 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,248 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,248 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,248 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,248 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,248 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,249 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,249 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,249 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,249 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,249 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,249 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,249 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,249 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,249 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,250 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,250 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,250 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,250 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,250 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,250 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,250 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,250 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,250 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,250 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,250 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,250 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,251 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,251 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,251 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,251 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,251 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,251 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,251 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,251 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,251 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,251 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,251 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,251 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,252 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,252 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,252 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,252 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,252 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,252 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,252 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,252 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,252 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,252 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,252 INFO     [evaluator.py:279] Setting fewshot random generator seed to 1234
# 2024-09-13:19:05:16,263 INFO     [task.py:428] Building contexts for mmlu_elementary_mathematics on rank 0...
# 100% 378/378 [00:00<00:00, 481.83it/s]
# 2024-09-13:19:05:17,067 INFO     [task.py:428] Building contexts for mmlu_high_school_physics on rank 0...
# 100% 151/151 [00:00<00:00, 501.14it/s]
# 2024-09-13:19:05:17,379 INFO     [task.py:428] Building contexts for mmlu_astronomy on rank 0...
# 100% 152/152 [00:00<00:00, 489.34it/s]
# 2024-09-13:19:05:17,698 INFO     [task.py:428] Building contexts for mmlu_high_school_statistics on rank 0...
# 100% 216/216 [00:00<00:00, 515.27it/s]
# 2024-09-13:19:05:18,129 INFO     [task.py:428] Building contexts for mmlu_abstract_algebra on rank 0...
# 100% 100/100 [00:00<00:00, 506.37it/s]
# 2024-09-13:19:05:18,333 INFO     [task.py:428] Building contexts for mmlu_high_school_computer_science on rank 0...
# 100% 100/100 [00:00<00:00, 494.81it/s]
# 2024-09-13:19:05:18,541 INFO     [task.py:428] Building contexts for mmlu_high_school_mathematics on rank 0...
# 100% 270/270 [00:00<00:00, 513.22it/s]
# 2024-09-13:19:05:19,084 INFO     [task.py:428] Building contexts for mmlu_college_mathematics on rank 0...
# 100% 100/100 [00:00<00:00, 513.46it/s]
# 2024-09-13:19:05:19,285 INFO     [task.py:428] Building contexts for mmlu_college_chemistry on rank 0...
# 100% 100/100 [00:00<00:00, 522.21it/s]
# 2024-09-13:19:05:19,483 INFO     [task.py:428] Building contexts for mmlu_high_school_chemistry on rank 0...
# 100% 203/203 [00:00<00:00, 503.54it/s]
# 2024-09-13:19:05:19,898 INFO     [task.py:428] Building contexts for mmlu_high_school_biology on rank 0...
# 100% 310/310 [00:00<00:00, 516.12it/s]
# 2024-09-13:19:05:20,516 INFO     [task.py:428] Building contexts for mmlu_college_computer_science on rank 0...
# 100% 100/100 [00:00<00:00, 489.85it/s]
# 2024-09-13:19:05:20,726 INFO     [task.py:428] Building contexts for mmlu_computer_security on rank 0...
# 100% 100/100 [00:00<00:00, 509.97it/s]
# 2024-09-13:19:05:20,928 INFO     [task.py:428] Building contexts for mmlu_electrical_engineering on rank 0...
# 100% 145/145 [00:00<00:00, 523.21it/s]
# 2024-09-13:19:05:21,215 INFO     [task.py:428] Building contexts for mmlu_college_biology on rank 0...
# 100% 144/144 [00:00<00:00, 527.83it/s]
# 2024-09-13:19:05:21,496 INFO     [task.py:428] Building contexts for mmlu_college_physics on rank 0...
# 100% 102/102 [00:00<00:00, 498.32it/s]
# 2024-09-13:19:05:21,707 INFO     [task.py:428] Building contexts for mmlu_anatomy on rank 0...
# 100% 135/135 [00:00<00:00, 394.65it/s]
# 2024-09-13:19:05:22,057 INFO     [task.py:428] Building contexts for mmlu_machine_learning on rank 0...
# 100% 112/112 [00:00<00:00, 335.70it/s]
# 2024-09-13:19:05:22,404 INFO     [task.py:428] Building contexts for mmlu_conceptual_physics on rank 0...
# 100% 235/235 [00:00<00:00, 322.70it/s]
# 2024-09-13:19:05:23,154 INFO     [task.py:428] Building contexts for mmlu_human_aging on rank 0...
# 100% 223/223 [00:00<00:00, 320.88it/s]
# 2024-09-13:19:05:23,867 INFO     [task.py:428] Building contexts for mmlu_business_ethics on rank 0...
# 100% 100/100 [00:00<00:00, 318.44it/s]
# 2024-09-13:19:05:24,190 INFO     [task.py:428] Building contexts for mmlu_management on rank 0...
# 100% 103/103 [00:00<00:00, 327.13it/s]
# 2024-09-13:19:05:24,516 INFO     [task.py:428] Building contexts for mmlu_college_medicine on rank 0...
# 100% 173/173 [00:00<00:00, 320.70it/s]
# 2024-09-13:19:05:25,072 INFO     [task.py:428] Building contexts for mmlu_clinical_knowledge on rank 0...
# 100% 265/265 [00:00<00:00, 325.75it/s]
# 2024-09-13:19:05:25,911 INFO     [task.py:428] Building contexts for mmlu_virology on rank 0...
# 100% 166/166 [00:00<00:00, 303.70it/s]
# 2024-09-13:19:05:26,480 INFO     [task.py:428] Building contexts for mmlu_professional_medicine on rank 0...
# 100% 272/272 [00:00<00:00, 305.72it/s]
# 2024-09-13:19:05:27,397 INFO     [task.py:428] Building contexts for mmlu_miscellaneous on rank 0...
# 100% 783/783 [00:01<00:00, 441.89it/s]
# 2024-09-13:19:05:29,244 INFO     [task.py:428] Building contexts for mmlu_nutrition on rank 0...
# 100% 306/306 [00:00<00:00, 517.79it/s]
# 2024-09-13:19:05:29,852 INFO     [task.py:428] Building contexts for mmlu_global_facts on rank 0...
# 100% 100/100 [00:00<00:00, 485.64it/s]
# 2024-09-13:19:05:30,064 INFO     [task.py:428] Building contexts for mmlu_marketing on rank 0...
# 100% 234/234 [00:00<00:00, 505.35it/s]
# 2024-09-13:19:05:30,540 INFO     [task.py:428] Building contexts for mmlu_professional_accounting on rank 0...
# 100% 282/282 [00:00<00:00, 509.25it/s]
# 2024-09-13:19:05:31,112 INFO     [task.py:428] Building contexts for mmlu_medical_genetics on rank 0...
# 100% 100/100 [00:00<00:00, 472.16it/s]
# 2024-09-13:19:05:31,330 INFO     [task.py:428] Building contexts for mmlu_public_relations on rank 0...
# 100% 110/110 [00:00<00:00, 525.64it/s]
# 2024-09-13:19:05:31,546 INFO     [task.py:428] Building contexts for mmlu_sociology on rank 0...
# 100% 201/201 [00:00<00:00, 508.76it/s]
# 2024-09-13:19:05:31,953 INFO     [task.py:428] Building contexts for mmlu_econometrics on rank 0...
# 100% 114/114 [00:00<00:00, 487.45it/s]
# 2024-09-13:19:05:32,194 INFO     [task.py:428] Building contexts for mmlu_us_foreign_policy on rank 0...
# 100% 100/100 [00:00<00:00, 528.68it/s]
# 2024-09-13:19:05:32,394 INFO     [task.py:428] Building contexts for mmlu_high_school_psychology on rank 0...
# 100% 545/545 [00:01<00:00, 513.25it/s]
# 2024-09-13:19:05:33,484 INFO     [task.py:428] Building contexts for mmlu_high_school_geography on rank 0...
# 100% 198/198 [00:00<00:00, 526.96it/s]
# 2024-09-13:19:05:33,871 INFO     [task.py:428] Building contexts for mmlu_human_sexuality on rank 0...
# 100% 131/131 [00:00<00:00, 511.28it/s]
# 2024-09-13:19:05:34,135 INFO     [task.py:428] Building contexts for mmlu_high_school_government_and_politics on rank 0...
# 100% 193/193 [00:00<00:00, 491.24it/s]
# 2024-09-13:19:05:34,540 INFO     [task.py:428] Building contexts for mmlu_high_school_microeconomics on rank 0...
# 100% 238/238 [00:00<00:00, 500.93it/s]
# 2024-09-13:19:05:35,028 INFO     [task.py:428] Building contexts for mmlu_high_school_macroeconomics on rank 0...
# 100% 390/390 [00:01<00:00, 256.08it/s]
# 2024-09-13:19:05:36,577 INFO     [task.py:428] Building contexts for mmlu_security_studies on rank 0...
# 100% 245/245 [00:00<00:00, 513.00it/s]
# 2024-09-13:19:05:37,071 INFO     [task.py:428] Building contexts for mmlu_professional_psychology on rank 0...
# 100% 612/612 [00:01<00:00, 440.44it/s]
# 2024-09-13:19:05:38,498 INFO     [task.py:428] Building contexts for mmlu_high_school_us_history on rank 0...
# 100% 204/204 [00:00<00:00, 322.51it/s]
# 2024-09-13:19:05:39,152 INFO     [task.py:428] Building contexts for mmlu_high_school_world_history on rank 0...
# 100% 237/237 [00:00<00:00, 340.51it/s]
# 2024-09-13:19:05:39,883 INFO     [task.py:428] Building contexts for mmlu_professional_law on rank 0...
# 100% 1534/1534 [00:04<00:00, 335.50it/s]
# 2024-09-13:19:05:44,606 INFO     [task.py:428] Building contexts for mmlu_high_school_european_history on rank 0...
# 100% 165/165 [00:00<00:00, 496.50it/s]
# 2024-09-13:19:05:44,953 INFO     [task.py:428] Building contexts for mmlu_philosophy on rank 0...
# 100% 311/311 [00:00<00:00, 508.36it/s]
# 2024-09-13:19:05:45,583 INFO     [task.py:428] Building contexts for mmlu_world_religions on rank 0...
# 100% 171/171 [00:00<00:00, 495.49it/s]
# 2024-09-13:19:05:45,940 INFO     [task.py:428] Building contexts for mmlu_international_law on rank 0...
# 100% 121/121 [00:00<00:00, 481.05it/s]
# 2024-09-13:19:05:46,201 INFO     [task.py:428] Building contexts for mmlu_formal_logic on rank 0...
# 100% 126/126 [00:00<00:00, 520.97it/s]
# 2024-09-13:19:05:46,456 INFO     [task.py:428] Building contexts for mmlu_prehistory on rank 0...
# 100% 324/324 [00:00<00:00, 488.07it/s]
# 2024-09-13:19:05:47,140 INFO     [task.py:428] Building contexts for mmlu_logical_fallacies on rank 0...
# 100% 163/163 [00:00<00:00, 497.54it/s]
# 2024-09-13:19:05:47,479 INFO     [task.py:428] Building contexts for mmlu_moral_disputes on rank 0...
# 100% 346/346 [00:00<00:00, 508.60it/s]
# 2024-09-13:19:05:48,185 INFO     [task.py:428] Building contexts for mmlu_moral_scenarios on rank 0...
# 100% 895/895 [00:01<00:00, 510.36it/s]
# 2024-09-13:19:05:50,007 INFO     [task.py:428] Building contexts for mmlu_jurisprudence on rank 0...
# 100% 108/108 [00:00<00:00, 496.78it/s]
# 2024-09-13:19:05:50,234 INFO     [task.py:428] Building contexts for truthfulqa_mc2 on rank 0...
# 100% 817/817 [00:01<00:00, 587.89it/s]
# 2024-09-13:19:05:51,711 INFO     [evaluator.py:485] Running loglikelihood requests
